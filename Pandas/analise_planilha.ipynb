# %%
import pandas as pd

# %%
df = pd.read_excel("dados/campeonato_futebol.xlsx")

# %%
df

# %%
df.dtypes

# %%
df.describe()

# %%
df.head(4)

# %%
df.tail(4)

# %%
desempenh_info=df[['Times','Pontos','Vitorias','Saldos_Gols']].set_index('Times')
desempenh_info

# %%
times_mais_vitorias=df[df['Vitorias']==df['Vitorias'].max()]
times_mais_vitorias

# %%
times_menos_vitorias=df[df['Vitorias']==df['Vitorias'].min()]
times_menos_vitorias

# %%
df['Gols_Pro'].value_counts()

# %%
correlacao=df['Gols_Pro'].corr(df['Pontos'])
correlacao
