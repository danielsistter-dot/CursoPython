# %%
import json

# %%
dados_receitas ={
    "Receitas":[
        {
            "Titulo":"Bolo de Chocolate",
            "Tempo de Preparo":"45 minutos",
            "Porcoes":8,
            "Ingredientes":[
                {"Ingrediente":"Farinha de Trigo","quantidade":"2 xicaras"},
                {"Ingrediente":"Açucar","quantidade":"1 xicaras"},
                {"Ingrediente":"Ovos","quantidade":"3 xicaras"},
                {"Ingrediente":"Leite","quantidade":"1 xicaras"},
                {"Ingrediente":"Manteiga","quantidade":"1/2 xicaras"}
            ]
        },
        {
            "Titulo":"Salada Caesar",
            "Tempo de Preparo":"20 minutos",
            "Porcoes":4,
            "Ingredientes":[
                {"Ingrediente":"Alface Romana","quantidade":"2 cabeça"},
                {"Ingrediente":"Croutons","quantidade":"1 xicaras"},
                {"Ingrediente":"Queijo Parmesão","quantidade":"1/2 xicaras"},
                {"Ingrediente":"Molho Caesar","quantidade":"1/4 xicaras"}
            ]
        },
           {
            "Titulo":"Pasta ao Pesto",
            "Tempo de Preparo":"30 minutos",
            "Porcoes":2,
            "Ingredientes":[
                {"Ingrediente":"Massa","quantidade":"200g"},
                {"Ingrediente":"Manjericão Fresco","quantidade":"1/2 xicaras"},
                {"Ingrediente":"Azeite de Oliva","quantidade":"1/3 xicaras"},
                {"Ingrediente":"Nozes","quantidade":"1/4 xicaras"},
                {"Ingrediente":"Queijo Parmesão","quantidade":"1/4 xicaras"}
            ]
        }
    ]
}

# %%
with open("dados/receitas.json","w",encoding="utf-8") as file:
    json.dump(dados_receitas, file, ensure_ascii=False, indent=4)
