# %%
import numpy as np

# %%
array =np.array([1,2,3,4,5])
array

# %%
soma= np.add(array,10)
soma

# %%
subtra=np.subtract(array,5)
subtra

# %%
multi=np.multiply(array,3)
multi

# %%
divide=np.divide(array,2)
divide

# %%
seno=np.sin(array)
seno

# %%
coseno=np.cos(array)
coseno

# %%
media=np.mean(array)
media

# %%
desviopadrao=np.std(array)
desviopadrao

# %%
compararmaior=array>3
compararmaior

# %%
resultado =np.sqrt(array) +np.power(array,2)
resultado

# %%
exponencial =np.exp(array)
exponencial

# %%
logaritimo =np.log(array)
logaritimo

# %%
arredondar= np.round(array/2)
arredondar

# %%
potencia = np.power(array,3)
potencia
