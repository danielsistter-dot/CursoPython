# %%
import numpy as np

# %%
array = np.array([10,20,30,40,50])
array
# Out:
# array([10, 20, 30, 40, 50])

# %%
posicao = np.where(array ==30)
posicao
# Out:
# (array([2]),)

# %%
notas = np.array    ([55,67,72,48,90,85,60,50])
notas
# Out:
# array([55, 67, 72, 48, 90, 85, 60, 50])

# %%
alunosaprovados=np.where(notas >60)
alunosaprovados
# Out:
# (array([1, 2, 4, 5]),)

# %%
notas[alunosaprovados]
# Out:
# array([67, 72, 90, 85])

# %%
notamaximo=np.max(notas)
notamaximo
# Out:
# np.int64(90)

# %%
indicemax=np.argmax(notas)
indicemax
# Out:
# np.int64(4)
