# %%
import numpy as np

# %%
array = np.array([[10,20,30],
                 [40,50,60],
                 [70,80,90]])
array
print(array.ndim)
print(array.shape)
array

# %%
print(array[1,2])

# %%
print(array[0])

# %%
print(array[:,1])

# %%
arraysub=array[0:2,1:3]
arraysub

# %%
mascara = array > 50
mascara

# %%
maiores50 = array[mascara]
maiores50

# %%
array[1,1] = 100
array
