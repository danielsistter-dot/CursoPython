# %%
import numpy as np

# %%
array_1d = np.array([1,2,3,4,5])
print(array_1d.ndim)
print(array_1d.shape)
array_1d

# %%
array_2d=np.array([[1,2,3,4,5]])
print(array_2d.ndim)
print(array_2d.shape)
array_2d

# %%
array_3d=np.array([[[1,2,3,4,5]]])
print(array_3d.ndim)
print(array_3d.shape)
array_3d

# %%
dados_teste = np.random.rand(10, 10)
print(dados_teste)

# %%
array_10_10 = np.random.rand(10, 10)

# Para ver o resultado e o formato (shape):
print(array_10_10)
print(f"\nFormato: {array_10_10.shape}")
